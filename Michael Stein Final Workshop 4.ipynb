# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv('data/tennis copy.csv')
df
# Out:
#       year                  tournament  start date type        surface  \
# 0     1998          Basel, Switzerland  1998-10-05   WS   Indoor: Hard
# 1     1998            Toulouse, France  1998-09-28   WS   Indoor: Hard
# 2     1998            Toulouse, France  1998-09-28   WS   Indoor: Hard
# 3     1998            Toulouse, France  1998-09-28   WS   Indoor: Hard
# 4     1998         Geneva, Switzerland  1998-08-24   CH  Outdoor: Clay
# ...    ...                         ...         ...  ...            ...
# 1174  2012  Australian Open, Australia  2012-01-16   GS  Outdoor: Hard
# 1175  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
# 1176  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
# 1177  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
# 1178  2012                 Doha, Qatar  2012-01-02  250  Outdoor: Hard
#
#            draw atp points  atp ranking tournament prize money round  ...  \
# ...

# %%
df = df[['player1 total points total', 'player2 total points total']]
df
# Out:
#       player1 total points total  player2 total points total
# 0                          103.0                       103.0
# 1                          106.0                       106.0
# 2                          148.0                       148.0
# 3                          130.0                       130.0
# 4                            NaN                         NaN
# ...                          ...                         ...
# 1174                       276.0                       276.0
# 1175                        86.0                        86.0
# 1176                        99.0                        99.0
# 1177                       173.0                       173.0
# 1178                         NaN                         NaN
#
# [1179 rows x 2 columns]

# %%
df.mean()
# Out:
# player1 total points total    160.726388
# player2 total points total    160.726388
# dtype: float64

# %%
#No difference in mean.

# %%
#QUESTION 2

df = pd.read_csv('data/college.csv')
df
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
sns.pairplot(df)

# %%
#Histograms in columns 5 and 17 look the most normal. Going to test those.

from scipy import stats

shapiro_test5 = stats.shapiro(df['Top10perc'].dropna())
shapiro_test5 #apparently not normal. Weird
# Out:
# ShapiroResult(statistic=0.8874172568321228, pvalue=2.4506751303874142e-23)

# %%
shapiro_test17 = stats.shapiro(df['Grad.Rate'].dropna())
shapiro_test17 #also not normal. Cool.
# Out:
# ShapiroResult(statistic=0.9947985410690308, pvalue=0.00941859744489193)

# %%
#Most of the plots are either skewed to the right or left, as evident by the high values the left or right. 
#This just indicates that that's where most of the data values are concentrated.

# %%
df.corr()
# Out:
#                  Apps    Accept    Enroll  Top10perc  Top25perc  F.Undergrad  \
# Apps         1.000000  0.943451  0.846822   0.338834   0.351640     0.814491
# Accept       0.943451  1.000000  0.911637   0.192447   0.247476     0.874223
# Enroll       0.846822  0.911637  1.000000   0.181294   0.226745     0.964640
# Top10perc    0.338834  0.192447  0.181294   1.000000   0.891995     0.141289
# Top25perc    0.351640  0.247476  0.226745   0.891995   1.000000     0.199445
# F.Undergrad  0.814491  0.874223  0.964640   0.141289   0.199445     1.000000
# P.Undergrad  0.398264  0.441271  0.513069  -0.105356  -0.053577     0.570512
# Outstate     0.050159 -0.025755 -0.155477   0.562331   0.489394    -0.215742
# Room.Board   0.164939  0.090899 -0.040232   0.371480   0.331490    -0.068890
# Books        0.132559  0.113525  0.112711   0.118858   0.115527     0.115550
# Personal     0.178731  0.200989  0.280929  -0.093316  -0.080810     0.317200
# ...

# %%
#Good correlation where values are greater than 0.8. Apps has a good correlation with Accept (0.943451), 
#Enroll (0.846822), and F. Undergrad (0.814491).
#Bad correlation where values are less than 80%. Apps has a bad correlation with Top10perc (0.338834), 
#Top25perc (0.351640), and P. Undergrad (0.398264).

# %%
ax = sns.boxplot(x = 'Private', y = 'Outstate', data = df)

# %%
#QUESTION 3

import pandas as pd
import seaborn as sns
import numpy as np

#Help from this notebook https://www.kaggle.com/nagakalyan2784/predicting-fuel-efficiency-for-automobile
column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight',
                'Acceleration', 'Model Year', 'Origin'] 
df = pd.read_csv('data/auto.csv', names=column_names,
                      na_values = "?", comment='\t',
                      sep=" ", skipinitialspace=True)

df.dropna()
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 2    18.0        8.0         307.0       130.0  3504.0          12.0
# 3    15.0        8.0         350.0       165.0  3693.0          11.5
# 4    18.0        8.0         318.0       150.0  3436.0          11.0
# 5    16.0        8.0         304.0       150.0  3433.0          12.0
# 6    17.0        8.0         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 394  27.0        4.0         140.0        86.0  2790.0          15.6
# 395  44.0        4.0          97.0        52.0  2130.0          24.6
# 396  32.0        4.0         135.0        84.0  2295.0          11.6
# 397  28.0        4.0         120.0        79.0  2625.0          18.6
# 398  31.0        4.0         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 2          70.0     1.0
# 3          70.0     1.0
# 4          70.0     1.0
# 5          70.0     1.0
# ...

# %%
df2 = df[['Horsepower', 'Weight', 'Model Year', 'MPG']]
dfx = pd.to_numeric(df2['MPG'], errors = 'coerce').to_frame().append(df2).dropna()
dfx.MPG = dfx.MPG.astype(np.float)
sns.pairplot(dfx, hue = 'Model Year') #with time, horsepower got stronger and weight got heavier. 
                                    #MPG decreased over the years; therefore, cars now require more gas to travel.

# %%
df3 = df[['Cylinders', 'MPG', 'Displacement', 'Horsepower', 'Weight', 'Acceleration']]
df3.dropna().reset_index()
# Out:
#      index  Cylinders   MPG  Displacement  Horsepower  Weight  Acceleration
# 0        2        8.0  18.0         307.0       130.0  3504.0          12.0
# 1        3        8.0  15.0         350.0       165.0  3693.0          11.5
# 2        4        8.0  18.0         318.0       150.0  3436.0          11.0
# 3        5        8.0  16.0         304.0       150.0  3433.0          12.0
# 4        6        8.0  17.0         302.0       140.0  3449.0          10.5
# ..     ...        ...   ...           ...         ...     ...           ...
# 387    394        4.0  27.0         140.0        86.0  2790.0          15.6
# 388    395        4.0  44.0          97.0        52.0  2130.0          24.6
# 389    396        4.0  32.0         135.0        84.0  2295.0          11.6
# 390    397        4.0  28.0         120.0        79.0  2625.0          18.6
# 391    398        4.0  31.0         119.0        82.0  2720.0          19.4
#
# [392 rows x 7 columns]

# %%
df3.mean()
# Out:
# Cylinders          5.458438
# Displacement     193.532746
# Horsepower       104.469388
# Weight          2970.261965
# Acceleration      15.555668
# dtype: float64

# %%
df3.std()
# Out:
# Cylinders         1.701577
# Displacement    104.379583
# Horsepower       38.491160
# Weight          847.904119
# Acceleration      2.749995
# dtype: float64

# %%
df3.median()
# Out:
# Cylinders          4.0
# Displacement     146.0
# Horsepower        93.5
# Weight          2800.0
# Acceleration      15.5
# dtype: float64

# %%
df4 = df.drop([10, 85]).dropna()
df4
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 2    18.0        8.0         307.0       130.0  3504.0          12.0
# 3    15.0        8.0         350.0       165.0  3693.0          11.5
# 4    18.0        8.0         318.0       150.0  3436.0          11.0
# 5    16.0        8.0         304.0       150.0  3433.0          12.0
# 6    17.0        8.0         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 394  27.0        4.0         140.0        86.0  2790.0          15.6
# 395  44.0        4.0          97.0        52.0  2130.0          24.6
# 396  32.0        4.0         135.0        84.0  2295.0          11.6
# 397  28.0        4.0         120.0        79.0  2625.0          18.6
# 398  31.0        4.0         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 2          70.0     1.0
# 3          70.0     1.0
# 4          70.0     1.0
# 5          70.0     1.0
# ...

# %%
df4.mean()
# Out:
# Cylinders          5.469231
# Displacement     193.991026
# Horsepower       104.223077
# Weight          2975.958974
# Acceleration      15.556923
# Model Year        76.005128
# Origin             1.579487
# dtype: float64

# %%
df.mean() #No major difference in mean, despite the lost data
# Out:
# Cylinders          5.458438
# Displacement     193.532746
# Horsepower       104.469388
# Weight          2970.261965
# Acceleration      15.555668
# Model Year        75.994962
# Origin             1.574307
# dtype: float64

# %%
#QUESTION 4

from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
from sklearn import datasets

print(load_boston()['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
boston = datasets.load_boston()
df = pd.DataFrame(boston.data, columns = boston.feature_names)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
#There is a crime rate per capita column (CRIM), no correlation between it and the rest of the data. 
#There is a higher correlation to crime rate in industrial areas than in residential areas, which makes 
#sense as more random robberies (pickpockets) can happen on the streets and house break-ins are less common. More of a correlation around highways too for an easy get-away after a robbery.
