# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import gdp as getgdp

gdp = getgdp()
print(gdp)
# Out:
#    Current and capital accounts - Households, Canada, quarterly  \
# 0                                           Quarterly
# 1     Table: 36-10-0112-01 (formerly CANSIM 380-0072)
# 2                                   Geography: Canada
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                           Estimates
# 7                                                 NaN
# 8           Compensation of employees (x 1,000,000) 1
# 9   Paid to residents by resident entities (x 1,00...
# 10  Paid to residents by non-resident entities (x ...
# 11             Plus: net mixed income (x 1,000,000) 1
# 12                           Non-farm (x 1,000,000) 1
# 13                               Farm (x 1,000,000) 1
# 14        Rental income of households (x 1,000,000) 1
# 15          Plus: net property income (x 1,000,000) 1
# ...
